# %%
from nutils import mesh, function, solver
from nutils.expression_v2 import Namespace
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import collections
# %matplotlib notebook

nelems = 5
deg = 2
topo, geom = mesh.rectilinear([np.linspace(0, 1, nelems+1)])
ns = Namespace()
ns.x = geom
ns.define_for('x',gradient= 'd', jacobians= ('dx', 'ds'), normal= 'nhat')  
ns.basis= topo.basis('discont', degree=deg)

f = 

res = topo.integral

# %%
bezier = topo.sample('bezier', 32)
nanjoin = lambda array, tri: np.insert(array.take(tri.flat, 0).astype(float),
    slice(tri.shape[1], tri.size, tri.shape[1]), np.nan, axis=0)
sampled_x = nanjoin(bezier.eval('x_0' @ ns), bezier.tri)
def plot_line(func, **arguments):
    plt.plot(sampled_x, nanjoin(bezier.eval(func, **arguments), bezier.tri))
    plt.xlabel('x_0')
    plt.xticks(np.linspace(0, 1, 5))


plot_line(ns.basis)
# Out:
# <img src="data:image/png;base64,..." width="640">
